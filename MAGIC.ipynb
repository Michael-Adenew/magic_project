# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Adenew/magic_project/blob/main/MAGIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# standard importanting of libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# where we'll be getting our dataset from this. UC Irvine department

# %% [markdown]
# ### Dataset:
# ### uci gamma ray dataset
# repository: https://archive.ics.uci.edu/dataset/159/magic+gamma+telescope
#
# The data set was generated by a Monte Carlo program, Corsika, described in:
#     D. Heck et al., CORSIKA, A Monte Carlo code to simulate extensive air showers,
#     Forschungszentrum Karlsruhe FZKA 6019 (1998).
# http://rexa.info/paper?id=ac6e674e9af20979b23d3ed4521f1570765e8d68
#
# The program was run with parameters allowing to observe events with energies down to below 50 GeV.
#
#
# ###

# %%
pd.read_csv("magic04.data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8bc347deb056> in <cell line: 0>()
# ----> 1 pd.read_csv("magic04.data")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %% [markdown]
# # New Section

# %%
#!unzip magic+gamma+telescope.zip

# %% [markdown]
# these were different attributes of the data listed on the site. the data doesn't come labeled with them so we're gonna do it ourselves.

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]



df = pd.read_csv("magic04.data", names=cols)
df.head()
#display(df)

# %% [markdown]
# this data set has two types of rays: gamma rays and hadron rays. we need to differentiate them for the sake of processing. will use a boolean sort of method to label either gamma as 0 or 1 and hadron as the other. doesn't matter which.

# %%
df["class"] = (df["class"] == "g").astype(int)

# %% [markdown]
# the goal of this machine learning example is that all of these samples fall into the category of gamma ray or hadron ray.
#
# using the listed values in the features (or the object's property), we want to create a model that can correctly categorize any given sample as gamma ray or hadron ray, using it's attribute values.

# %%
df.head()

# %%
for label in cols[:-1]:
  plt.hist(df[df["class"] == 1][label], color="blue", label="gamma", alpha=0.7, density=True)
  plt.hist(df[df["class"] == 0][label], color="red", label="hadron", alpha=0.7, density=True)
  plt.title(label)
  plt.ylabel("Probability")
  plt.xlabel(label)
  plt.legend()
  plt.show()

# %% [markdown]
# #creating our train, validation, test datasets

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])

# %%
def scale_datset(dataframe, oversample = False):
  x = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values

  scaler = StandardScaler()
  x = scaler.fit_transform(x)


  if oversample:
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x, y)


  data = np.hstack((x, np.reshape(y, (-1, 1))))

  return data, x, y

# %% [markdown]
# #personal note: read into what transform actually does. Is it related to transformers by any chance?

# %%
train, X_train, y_train = scale_datset(train, oversample=True)
valid, X_valid, y_valid = scale_datset(valid, oversample = False)
test, X_test, y_test = scale_datset(test, oversample = False)
